# %%
import scipy.io
import matplotlib.pyplot as plt

d = scipy.io.loadmat('D.mat')

for key, value in d.items() :
    mat = value

print(mat)
plt.figure(figsize=(8, 6), dpi=320)

plt.imshow(mat, cmap='gist_heat', interpolation='nearest', aspect=1)
#plt.savefig("heatplot.png")
plt.show()
# Out:
# [[ 0.          0.02601417  0.06961516 ...,  0.04374418  1.15120154
#    0.99861976]
#  [ 0.02601417  0.          0.07266085 ...,  0.03478884  1.15120154
#    1.01045433]
#  [ 0.06961516  0.07266085  0.         ...,  0.07266085  1.12598908
#    0.99861976]
#  ...,
#  [ 0.04374418  0.03478884  0.07266085 ...,  0.          1.12598908
#    0.99861976]
#  [ 1.15120154  1.15120154  1.12598908 ...,  1.12598908  0.          0.13260893]
#  [ 0.99861976  1.01045433  0.99861976 ...,  0.99861976  0.13260893  0.        ]]
