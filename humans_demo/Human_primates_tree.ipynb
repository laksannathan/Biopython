# %%
from  Bio import Phylo

# %%
tree = Phylo.read("../../primates_tree", 'newick')
print(tree)
# Out:
# Tree(rooted=False, weight=1.0)
#     Clade()
#         Clade(branch_length=0.00298, name='Berber')
#         Clade(branch_length=0.00297, name='Yoruba')
#         Clade(branch_length=0.00054, confidence=0.959)
#             Clade(branch_length=0.00853, name='Chinese')
#             Clade(branch_length=0.08096, confidence=0.975)
#                 Clade(branch_length=0.1049, name='Georgian')
#                 Clade(branch_length=0.12635, confidence=0.992)
#                     Clade(branch_length=0.22385, confidence=0.997)
#                         Clade(branch_length=0.14329)
#                             Clade(branch_length=0.0, name='Pan_paniscus_1')
#                             Clade(branch_length=0.0, name='Pan_paniscus_2')
#                         Clade(branch_length=0.35998, confidence=0.917)
#                             Clade(branch_length=0.13786, name='Gorilla_gorilla_gorilla')
#                             Clade(branch_length=1.27547, confidence=0.992)
# ...

# %%
Phylo.draw(tree)
